# %%
import time
import psutil
import matplotlib.pyplot as plt 
import numpy as np

# %%
# Let us create some random data
mu, sigma = 5, 300 # mean and standard deviation
error=np.random.normal(mu, sigma, 1000)

x = np.arange(-500 ,  500 )
y = (2.5 * x) + error

plt.plot(x, y, 'o', markersize=2)

plt.show()

# %%
# %matplotlib notebook 
plt.rcParams['animation.html'] = 'jshtml'

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
b_current = 0 
m_current = 0

learningRate = 0.0000001
num_iteration = 700 

precision = 0.1


previous_step_size = 1 

n = float(len(y)) 
print("Sample size", n)


oldCost=0
# Start of iterations
# Capital X and Y are numpy Arrays
# These two variables are just for visualtion 
xx, costHist = [], [] 
y_prediction = m_current * x + b_current
initCost= (1/n) * sum (( y - y_prediction)**2)

ax.set_xlim(left = 0, right=num_iteration)
ax.set_ylim(bottom = 0, top=initCost)
# Let's start with main iterative part of gradient descent algorithm 

for i in range(num_iteration):
    
    # Calculate the prediction with current regression coefficients. 
    y_prediction = m_current * x + b_current
    
    # We compute costs just for monitoring 
    cost= (1/n) * sum (( y - y_prediction)**2)

    # calculate gradients. 
    m_gradient = (-1.0/n) * sum (x*(y - y_prediction) )
    b_gradient = (-1.0/n) * sum (y - y_prediction)
    
    # update the weights - Regression Coefficients 
    m_current = m_current - learningRate * m_gradient
    b_current = b_current - learningRate * b_gradient
    
    # Stop if the cost is not descreasing 
    if(abs(cost - oldCost) <= precision):
        print("Stoped at iteration", i)
        break
    
    oldCost = cost
    
    # Visualization 
    xx.append(i)
    costHist.append(cost)    
    ax.plot(xx, costHist, color='blue')


    fig.canvas.draw()
    
    if(i % 10 ==0):
        print("Iteration No.=", i , " Cost=", cost) 

print("m = ", m_current, " b=", b_current)
# Out:
# Sample size 1000.0
# Iteration No.= 0  Cost= 597082.2458702526
# Iteration No.= 10  Cost= 519602.2593936513
# Iteration No.= 20  Cost= 454062.6728382575
# Iteration No.= 30  Cost= 398623.3574537684
# Iteration No.= 40  Cost= 351727.76576354314
# Iteration No.= 50  Cost= 312059.22900370386
# Iteration No.= 60  Cost= 278503.98954090726
# Iteration No.= 70  Cost= 250119.9303447629
# Iteration No.= 80  Cost= 226110.12354480952
# Iteration No.= 90  Cost= 205800.4554054572
# Iteration No.= 100  Cost= 188620.6995042747
# Iteration No.= 110  Cost= 174088.50671280824
# Iteration No.= 120  Cost= 161795.86247303803
# Iteration No.= 130  Cost= 151397.6311358341
# Iteration No.= 140  Cost= 142601.86572538663
# Iteration No.= 150  Cost= 135161.61106074165
# Iteration No.= 160  Cost= 128867.97009396512
# Iteration No.= 170  Cost= 123544.23879128396
# Iteration No.= 180  Cost= 119040.94488461054
# Iteration No.= 190  Cost= 115231.65119845788
# Iteration No.= 200  Cost= 112009.4057239389
# Iteration No.= 210  Cost= 109283.73876998998
# Iteration No.= 220  Cost= 106978.12288204468
# Iteration No.= 230  Cost= 105027.82421129946
# Iteration No.= 240  Cost= 103378.08500833531
# Iteration No.= 250  Cost= 101982.58621168978
# Iteration No.= 260  Cost= 100802.14696609504
# Iteration No.= 270  Cost= 99803.62455727621
# Iteration No.= 280  Cost= 98958.98387721978
# Iteration No.= 290  Cost= 98244.5102936596
# Iteration No.= 300  Cost= 97640.14382383249
# Iteration No.= 310  Cost= 97128.91591836594
# Iteration No.= 320  Cost= 96696.47304210434
# Iteration No.= 330  Cost= 96330.67367564361
# Iteration No.= 340  Cost= 96021.24742274827
# Iteration No.= 350  Cost= 95759.50665254325
# Iteration No.= 360  Cost= 95538.10258037732
# Iteration No.= 370  Cost= 95350.81893893579
# Iteration No.= 380  Cost= 95192.39744658982
# Iteration No.= 390  Cost= 95058.39017272636
# Iteration No.= 400  Cost= 94945.03465497814
# Iteration No.= 410  Cost= 94849.14826207544
# Iteration No.= 420  Cost= 94768.03883637802
# Iteration No.= 430  Cost= 94699.42910724385
